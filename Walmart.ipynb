# %% [markdown]
# **STEP 1 DATA LOADING**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "E:/Data Analyst/walmart/Walmart.csv"
df = pd.read_csv(file_path)
df
# Out:
#        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10020 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price         object
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %% [markdown]
# - Here Unit_price and date has datatype as object

# %%
df.describe()
# Out:
#          invoice_id      quantity        rating  profit_margin
# count  10051.000000  10020.000000  10051.000000   10051.000000
# mean    5025.741220      2.353493      5.825659       0.393791
# std     2901.174372      1.602658      1.763991       0.090669
# min        1.000000      1.000000      3.000000       0.180000
# 25%     2513.500000      1.000000      4.000000       0.330000
# 50%     5026.000000      2.000000      6.000000       0.330000
# 75%     7538.500000      3.000000      7.000000       0.480000
# max    10000.000000     10.000000     10.000000       0.570000

# %% [markdown]
# **STEP 2 Remove Duplicate values**

# %%
df.duplicated().sum()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %% [markdown]
# - here .sum() will give sum of true how many duplicate are there

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %% [markdown]
# - Here unit_price and quantity has 31 null values in each

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# **STEP 3 Replacing and type casting**

# %%
df['unit_price'] = df['unit_price'].str.replace('$', '').astype(float)

df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10000 non-null  int64
#  1   Branch          10000 non-null  object
#  2   City            10000 non-null  object
#  3   category        10000 non-null  object
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            10000 non-null  object
#  7   time            10000 non-null  object
#  8   payment_method  10000 non-null  object
#  9   rating          10000 non-null  float64
#  10  profit_margin   10000 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 937.5+ KB

# %% [markdown]
# **STEP 4 Work on null values**

# %%
df['unit_price'].fillna(df['unit_price'].mean(), inplace=True)

# %%
df['quantity'].fillna(df['quantity'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='object')

# %% [markdown]
# **STEP 5 Convert 'date' column to datetime format**

# %%
df['date'] = pd.to_datetime(df['date'], format="%d/%m/%y")

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity       date      time payment_method  rating  profit_margin
# 0       7.0 2019-01-05  13:08:00        Ewallet     9.1           0.48
# 1       5.0 2019-03-08  10:29:00           Cash     9.6           0.48
# 2       7.0 2019-03-03  13:23:00    Credit card     7.4           0.33
# 3       8.0 2019-01-27  20:33:00        Ewallet     8.4           0.33
# 4       7.0 2019-02-08  10:37:00        Ewallet     5.3           0.48

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['we ekday'] = df['date'].dt.day_name()

# %% [markdown]
# **Step 6 Convert 'time' to hour of day**

# %%
df['time'] = pd.to_datetime(df['time'], format="%H:%M:%S").dt.hour

# %%
df
# Out:
#       invoice_id   Branch         City                category  unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty       74.69
# 1              2  WALM048    Harlingen  Electronic accessories       15.28
# 2              3  WALM067  Haltom City      Home and lifestyle       46.33
# 3              4  WALM064      Bedford       Health and beauty       58.22
# 4              5  WALM013       Irving       Sports and travel       86.31
# ...          ...      ...          ...                     ...         ...
# 9995        9996  WALM056      Rowlett     Fashion accessories       37.00
# 9996        9997  WALM030   Richardson      Home and lifestyle       58.00
# 9997        9998  WALM050     Victoria     Fashion accessories       52.00
# 9998        9999  WALM032        Tyler      Home and lifestyle       79.00
# 9999       10000  WALM069     Rockwall     Fashion accessories       62.00
#
# ...

# %% [markdown]
# **STEP 7 Categorize time periods**

# %%
def categorize_time(hour):
    if 5 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    else:
        return "Evening"

# %%
df['sales_period'] = df['time'].apply(categorize_time)

# %%
df
# Out:
#       invoice_id   Branch         City                category  unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty       74.69
# 1              2  WALM048    Harlingen  Electronic accessories       15.28
# 2              3  WALM067  Haltom City      Home and lifestyle       46.33
# 3              4  WALM064      Bedford       Health and beauty       58.22
# 4              5  WALM013       Irving       Sports and travel       86.31
# ...          ...      ...          ...                     ...         ...
# 9995        9996  WALM056      Rowlett     Fashion accessories       37.00
# 9996        9997  WALM030   Richardson      Home and lifestyle       58.00
# 9997        9998  WALM050     Victoria     Fashion accessories       52.00
# 9998        9999  WALM032        Tyler      Home and lifestyle       79.00
# 9999       10000  WALM069     Rockwall     Fashion accessories       62.00
#
# ...

# %% [markdown]
# **STEP 8 Create total sales column**

# %%
df['total_sales'] = df['unit_price'] * df['quantity']

# %%
def rating_category(rating):
    if rating < 4:
        return "Low"
    elif 4 <= rating < 8:
        return "Medium"
    else:
        return "High"

# %%
df['rating_category'] = df['rating'].apply(rating_category)

# %%
df
# Out:
#       invoice_id   Branch         City                category  unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty       74.69
# 1              2  WALM048    Harlingen  Electronic accessories       15.28
# 2              3  WALM067  Haltom City      Home and lifestyle       46.33
# 3              4  WALM064      Bedford       Health and beauty       58.22
# 4              5  WALM013       Irving       Sports and travel       86.31
# ...          ...      ...          ...                     ...         ...
# 9995        9996  WALM056      Rowlett     Fashion accessories       37.00
# 9996        9997  WALM030   Richardson      Home and lifestyle       58.00
# 9997        9998  WALM050     Victoria     Fashion accessories       52.00
# 9998        9999  WALM032        Tyler      Home and lifestyle       79.00
# 9999       10000  WALM069     Rockwall     Fashion accessories       62.00
#
# ...

# %% [markdown]
# # Sales Trend Analysis

# %%
df.groupby('year')['total_sales'].sum().sort_values(ascending = False).plot(kind='bar', color='skyblue', edgecolor='black',figsize=(10, 5))
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.title("Sales Trend Analysis (Yearly Sales)")
plt.show()

# %%
df['month'] = df['date'].dt.strftime('%b')
df
# Out:
#       invoice_id   Branch         City                category  unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty       74.69
# 1              2  WALM048    Harlingen  Electronic accessories       15.28
# 2              3  WALM067  Haltom City      Home and lifestyle       46.33
# 3              4  WALM064      Bedford       Health and beauty       58.22
# 4              5  WALM013       Irving       Sports and travel       86.31
# ...          ...      ...          ...                     ...         ...
# 9995        9996  WALM056      Rowlett     Fashion accessories       37.00
# 9996        9997  WALM030   Richardson      Home and lifestyle       58.00
# 9997        9998  WALM050     Victoria     Fashion accessories       52.00
# 9998        9999  WALM032        Tyler      Home and lifestyle       79.00
# 9999       10000  WALM069     Rockwall     Fashion accessories       62.00
#
# ...

# %%
df.groupby('month')['total_sales'].sum().sort_values(ascending = False).plot(kind='line', color='skyblue',figsize=(10, 5))
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.title("Sales Trend Analysis (Monthly Sales)")
plt.show()

# %% [markdown]
# # Category-Wise Sales Analysis

# %%
df['category'].value_counts()
# Out:
# category
# Fashion accessories       4553
# Home and lifestyle        4536
# Electronic accessories     419
# Food and beverages         174
# Sports and travel          166
# Health and beauty          152
# Name: count, dtype: int64

# %%
 df['category'].nunique()
# Out:
# 6

# %%
df.groupby('category')['total_sales'].sum().sort_values(ascending = False).plot(kind='bar', color='orange', edgecolor='black',figsize=(10,5))
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# # Sales Analysis by Sales Period(sales time)

# %%
sales_by_period = df.groupby('sales_period')['total_sales'].sum().sort_values(ascending=False)


plt.figure(figsize=(8, 5))
sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm", edgecolor="black")


plt.xlabel("Sales Period")
plt.ylabel("Total Sales")
plt.title("Total Sales by Sales Period")
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\rutika.DESKTOP-2661VF0\AppData\Local\Temp\ipykernel_5724\2814022813.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm", edgecolor="black")

# %% [markdown]
# # Display top 10 city with highest sales

# %%
df.groupby('City')['total_sales'].sum().sort_values(ascending=False).head(10).plot(kind='pie',autopct='%1.1f%%', figsize=(8, 8))
plt.title('Top 10 Cities by Total Sales', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Top 10 Cities by Total Sales')

# %% [markdown]
# # customer ratings for products

# %%
df.groupby('category')['rating'].sum()
# Out:
# category
# Electronic accessories     2477.2
# Fashion accessories       26325.2
# Food and beverages         1237.7
# Health and beauty          1064.5
# Home and lifestyle        26049.0
# Sports and travel          1148.1
# Name: rating, dtype: float64

# %%
rating_sales = df.groupby('category')['rating'].sum().sort_values( ascending=True)


# Generate a gradient of colors using the 'viridis' colormap
colors = plt.cm.viridis(np.linspace(0, 1, len(rating_sales)))

rating_sales.plot(
    kind='barh', 
    color=colors,
    edgecolor='black', 
    figsize=(8, 6)
)
plt.title('Customer Ratings by Product Category')
plt.xlabel('Rating')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# **Pyment method mostly used**

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Credit card    4257
# Ewallet        3911
# Cash           1832
# Name: count, dtype: int64

# %% [markdown]
# **Profit Margin by Product Category**

# %%
category_profit_margin = df.groupby('category')['profit_margin'].mean().sort_values(ascending=False)


plt.figure(figsize=(10, 6))
category_profit_margin.plot(kind='bar', color='teal', edgecolor='black')
plt.title('Average Profit Margin by Product Category', fontsize=14)
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('Average Profit Margin', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Connection with mysql**

# %%
import pymysql #this will work as adapter
from sqlalchemy import create_engine

# %%
# "mysql+pymysql://user:password@localhost:3306/db_name"
engine_mysql = create_engine("mysql+pymysql://root:root@localhost:3306/walmart_db")

try:
    engine_mysql
    print("Connection Successed to mysql")
except:
    print("Unable to connect")

# %%
df.to_sql(name='walmart', con=engine_mysql, if_exists='append', index=False)

# %%
df.to_csv("walmart_clean_data.csv", index=False)
